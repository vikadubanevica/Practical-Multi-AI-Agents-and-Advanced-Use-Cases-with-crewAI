# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 155 packages in 1.43s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# tiktoken   ------------------------------     0 B/1.10 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# tiktoken   ------------------------------     0 B/1.10 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# tiktoken   ------------------------------     0 B/1.10 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# protobuf   ------------------------------     0 B/315.86 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# lance-namespace-urllib3-client ------------------------------     0 B/309.68 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# rich       ------------------------------     0 B/303.20 KiB
# lance-namespace-urllib3-client ------------------------------     0 B/309.68 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# googleapis-common-protos ------------------------------     0 B/293.69 KiB
# rich       ------------------------------     0 B/303.20 KiB
# lance-namespace-urllib3-client ------------------------------     0 B/309.68 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# python-docx ------------------------------     0 B/247.06 KiB
# googleapis-common-protos ------------------------------     0 B/293.69 KiB
# rich       ------------------------------     0 B/303.20 KiB
# lance-namespace-urllib3-client ------------------------------     0 B/309.68 KiB
# protobuf   ------------------------------     0 B/315.86 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# watchfiles ------------------------------     0 B/445.39 KiB
# pydantic   ------------------------------     0 B/460.86 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# tiktoken   ------------------------------     0 B/1.10 MiB
# pygments   ------------------------------     0 B/1.17 MiB
# aiohttp    ------------------------------     0 B/1.68 MiB
# kubernetes ------------------------------     0 B/1.92 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/151)
# multidict  ------------------------------ 46.84 KiB/240.52 KiB
# openpyxl   ------------------------------ 14.80 KiB/245.03 KiB
# python-docx ------------------------------ 14.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 32.00 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 14.80 KiB/293.69 KiB
# rich       ------------------------------ 46.68 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 27.52 KiB/309.68 KiB
# protobuf   ------------------------------ 62.81 KiB/315.86 KiB
# pypdf      ------------------------------ 30.85 KiB/328.43 KiB
# jiter      ------------------------------ 62.73 KiB/354.18 KiB
# rpds-py    ------------------------------ 62.84 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 30.81 KiB/382.26 KiB
# watchfiles ------------------------------ 62.84 KiB/445.39 KiB
# httptools  ------------------------------ 16.00 KiB/445.92 KiB
# pydantic   ------------------------------ 30.81 KiB/460.86 KiB
# crewai     ------------------------------ 30.78 KiB/462.12 KiB
# mpmath     ------------------------------ 46.77 KiB/523.63 KiB
# huggingface-hub ------------------------------ 31.89 KiB/630.37 KiB
# crewai-tools ------------------------------ 15.89 KiB/723.68 KiB
# pyvis      ------------------------------ 14.77 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/151)
# multidict  ------------------------------ 142.84 KiB/240.52 KiB
# openpyxl   ------------------------------ 14.80 KiB/245.03 KiB
# python-docx ------------------------------ 30.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 156.41 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 30.80 KiB/293.69 KiB
# rich       ------------------------------ 46.68 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 59.52 KiB/309.68 KiB
# protobuf   ------------------------------ 158.81 KiB/315.86 KiB
# pypdf      ------------------------------ 78.85 KiB/328.43 KiB
# jiter      ------------------------------ 158.81 KiB/354.18 KiB
# rpds-py    ------------------------------ 158.84 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 46.81 KiB/382.26 KiB
# watchfiles ------------------------------ 171.93 KiB/445.39 KiB
# httptools  ------------------------------ 157.22 KiB/445.92 KiB
# pydantic   ------------------------------ 46.81 KiB/460.86 KiB
# crewai     ------------------------------ 46.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 13.09 KiB/473.85 KiB
# mpmath     ------------------------------ 139.99 KiB/523.63 KiB
# huggingface-hub ------------------------------ 47.79 KiB/630.37 KiB
# crewai-tools ------------------------------ 15.89 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/151)
# multidict  ------------------------------ 142.84 KiB/240.52 KiB
# openpyxl   ------------------------------ 14.80 KiB/245.03 KiB
# python-docx ------------------------------ 30.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 156.41 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 30.80 KiB/293.69 KiB
# rich       ------------------------------ 46.68 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 59.52 KiB/309.68 KiB
# protobuf   ------------------------------ 158.81 KiB/315.86 KiB
# pypdf      ------------------------------ 78.85 KiB/328.43 KiB
# jiter      ------------------------------ 158.81 KiB/354.18 KiB
# rpds-py    ------------------------------ 158.84 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 46.81 KiB/382.26 KiB
# watchfiles ------------------------------ 171.93 KiB/445.39 KiB
# httptools  ------------------------------ 157.22 KiB/445.92 KiB
# pydantic   ------------------------------ 46.81 KiB/460.86 KiB
# crewai     ------------------------------ 46.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 13.09 KiB/473.85 KiB
# mpmath     ------------------------------ 139.99 KiB/523.63 KiB
# huggingface-hub ------------------------------ 47.79 KiB/630.37 KiB
# crewai-tools ------------------------------ 15.89 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/151)
# multidict  ------------------------------ 142.84 KiB/240.52 KiB
# openpyxl   ------------------------------ 30.80 KiB/245.03 KiB
# python-docx ------------------------------ 30.81 KiB/247.06 KiB
# bcrypt     ------------------------------ 156.41 KiB/271.72 KiB
# googleapis-common-protos ------------------------------
84 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 93.36 KiB/382.26 KiB
# watchfiles ------------------------------ 319.93 KiB/445.39 KiB
# httptools  ------------------------------ 301.22 KiB/445.92 KiB
# pydantic   ------------------------------ 173.41 KiB/460.86 KiB
# crewai     ------------------------------ 78.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 208.00 KiB/473.85 KiB
# mpmath     ------------------------------ 271.99 KiB/523.63 KiB
# huggingface-hub ------------------------------ 270.04 KiB/630.37 KiB
# crewai-tools ------------------------------ 47.89 KiB/723.68 KiB
# pyvis      ------------------------------ 278.03 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/151)
# opentelemetry-semantic-conventions ------------------------------ 14.79 KiB/226.19 KiB
# tomli      ------------------------------ 48.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 46.80 KiB/245.03 KiB
# python-docx ------------------------------ 78.81 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 78.69 KiB/293.69 KiB
# rich       ------------------------------ 126.57 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 126.82 KiB/309.68 KiB
# protobuf   ------------------------------ 261.69 KiB/315.86 KiB
# pypdf      ------------------------------ 270.08 KiB/328.43 KiB
# jiter      ------------------------------ 350.04 KiB/354.18 KiB
# rpds-py    ------------------------------ 324.39 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 93.36 KiB/382.26 KiB
# watchfiles ------------------------------ 349.45 KiB/445.39 KiB
# httptools  ------------------------------ 317.22 KiB/445.92 KiB
# pydantic   ------------------------------ 237.19 KiB/460.86 KiB
# crewai     ------------------------------ 94.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 242.61 KiB/473.85 KiB
# mpmath     ------------------------------ 335.99 KiB/523.63 KiB
# huggingface-hub ------------------------------ 302.04 KiB/630.37 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/151)
# opentelemetry-semantic-conventions ------------------------------ 14.79 KiB/226.19 KiB
# tomli      ------------------------------ 80.00 KiB/238.11 KiB
# openpyxl   ------------------------------ 46.80 KiB/245.03 KiB
# python-docx ------------------------------ 94.81 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 94.80 KiB/293.69 KiB
# rich       ------------------------------ 142.57 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 142.82 KiB/309.68 KiB
# protobuf   ------------------------------ 286.81 KiB/315.86 KiB
# pypdf      ------------------------------ 315.66 KiB/328.43 KiB
# rpds-py    ------------------------------ 350.84 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 109.36 KiB/382.26 KiB
# watchfiles ------------------------------ 381.45 KiB/445.39 KiB
# httptools  ------------------------------ 365.22 KiB/445.92 KiB
# pydantic   ------------------------------ 269.41 KiB/460.86 KiB
# crewai     ------------------------------ 110.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 268.91 KiB/473.85 KiB
# mpmath     ------------------------------ 357.83 KiB/523.63 KiB
# huggingface-hub ------------------------------ 334.04 KiB/630.37 KiB
# crewai-tools ------------------------------ 63.89 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/151)
# frozenlist ------------------------------     0 B/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.79 KiB/226.19 KiB
# tomli      ------------------------------ 85.40 KiB/238.11 KiB
# openpyxl   ------------------------------ 62.80 KiB/245.03 KiB
# python-docx ------------------------------ 94.81 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 94.80 KiB/293.69 KiB
# rich       ------------------------------ 174.79 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 158.82 KiB/309.68 KiB
# protobuf   ------------------------------ 302.81 KiB/315.86 KiB
# pypdf      ------------------------------ 315.66 KiB/328.43 KiB
# prompt-toolkit ------------------------------ 125.36 KiB/382.26 KiB
# watchfiles ------------------------------ 386.36 KiB/445.39 KiB
# httptools  ------------------------------ 381.22 KiB/445.92 KiB
# pydantic   ------------------------------ 269.41 KiB/460.86 KiB
# crewai     ------------------------------ 110.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 284.91 KiB/473.85 KiB
# mpmath     ------------------------------ 383.99 KiB/523.63 KiB
# huggingface-hub ------------------------------ 350.04 KiB/630.37 KiB
# crewai-tools ------------------------------ 63.89 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/151)
# python-dateutil ------------------------------     0 B/224.50 KiB
# frozenlist ------------------------------ 15.89 KiB/225.65 KiB
# opentelemetry-semantic-conventions ------------------------------ 30.79 KiB/226.19 KiB
# tomli      ------------------------------ 117.40 KiB/238.11 KiB
# openpyxl   ------------------------------ 62.80 KiB/245.03 KiB
# python-docx ------------------------------ 110.81 KiB/247.06 KiB
# googleapis-common-protos ------------------------------ 110.80 KiB/293.69 KiB
# rich       ------------------------------ 174.79 KiB/303.20 KiB
# lance-namespace-urllib3-client ------------------------------ 158.82 KiB/309.68 KiB
# protobuf   ------------------------------ 315.86 KiB/315.86 KiB
# pypdf      ------------------------------ 328.43 KiB/328.43 KiB
# prompt-toolkit ------------------------------ 125.36 KiB/382.26 KiB
# watchfiles ------------------------------ 418.26 KiB/445.39 KiB
# httptools  ------------------------------ 398.69 KiB/445.92 KiB
# pydantic   ------------------------------ 291.18 KiB/460.86 KiB
# crewai     ------------------------------ 110.78 KiB/462.12 KiB
# youtube-transcript-api ------------------------------
KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 8.62 KiB/175.99 KiB
# websockets ------------------------------ 30.84 KiB/180.30 KiB
# fsspec     ------------------------------ 32.00 KiB/197.85 KiB
# propcache  ------------------------------ 127.61 KiB/205.11 KiB
# charset-normalizer ------------------------------ 157.06 KiB/209.04 KiB
# cffi       ------------------------------ 188.39 KiB/210.52 KiB
# python-dateutil ------------------------------ 223.43 KiB/224.50 KiB
# opentelemetry-semantic-conventions ------------------------------ 126.79 KiB/226.19 KiB
# openpyxl   ------------------------------ 141.60 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 190.80 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 269.03 KiB/309.68 KiB
# prompt-toolkit ------------------------------ 293.58 KiB/382.26 KiB
# crewai     ------------------------------ 142.78 KiB/462.12 KiB
# huggingface-hub ------------------------------ 494.04 KiB/630.37 KiB
# crewai-tools ------------------------------ 144.00 KiB/723.68 KiB
# pyvis      ------------------------------ 627.31 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/151)
# docker     ------------------------------     0 B/144.31 KiB
# certifi    ------------------------------ 14.80 KiB/150.08 KiB
# oauthlib   ------------------------------ 30.84 KiB/156.31 KiB
# instructor ------------------------------ 17.04 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 30.77 KiB/175.99 KiB
# websockets ------------------------------ 39.83 KiB/180.30 KiB
# fsspec     ------------------------------ 47.89 KiB/197.85 KiB
# propcache  ------------------------------ 143.61 KiB/205.11 KiB
# charset-normalizer ------------------------------ 173.06 KiB/209.04 KiB
# cffi       ------------------------------ 210.52 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 126.79 KiB/226.19 KiB
# openpyxl   ------------------------------ 141.60 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 206.80 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 269.03 KiB/309.68 KiB
# prompt-toolkit ------------------------------ 293.58 KiB/382.26 KiB
# crewai     ------------------------------ 158.34 KiB/462.12 KiB
# huggingface-hub ------------------------------ 494.04 KiB/630.37 KiB
# crewai-tools ------------------------------ 144.00 KiB/723.68 KiB
# pyvis      ------------------------------ 646.03 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/151)
# jinja2     ------------------------------     0 B/131.74 KiB
# docker     ------------------------------     0 B/144.31 KiB
# certifi    ------------------------------ 30.80 KiB/150.08 KiB
# oauthlib   ------------------------------ 30.84 KiB/156.31 KiB
# instructor ------------------------------ 17.04 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 46.77 KiB/175.99 KiB
# websockets ------------------------------ 55.83 KiB/180.30 KiB
# fsspec     ------------------------------ 62.62 KiB/197.85 KiB
# propcache  ------------------------------ 159.61 KiB/205.11 KiB
# charset-normalizer ------------------------------ 189.06 KiB/209.04 KiB
# cffi       ------------------------------ 210.52 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 126.79 KiB/226.19 KiB
# openpyxl   ------------------------------ 157.60 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 206.80 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 270.82 KiB/309.68 KiB
# prompt-toolkit ------------------------------ 309.58 KiB/382.26 KiB
# crewai     ------------------------------ 158.34 KiB/462.12 KiB
# huggingface-hub ------------------------------ 510.04 KiB/630.37 KiB
# crewai-tools ------------------------------ 144.00 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4/151)
# orjson     ------------------------------     0 B/130.45 KiB
# jinja2     ------------------------------ 16.00 KiB/131.74 KiB
# docker     ------------------------------ 14.81 KiB/144.31 KiB
# certifi    ------------------------------ 33.21 KiB/150.08 KiB
# oauthlib   ------------------------------ 41.66 KiB/156.31 KiB
# instructor ------------------------------ 17.04 KiB/173.98 KiB
# opentelemetry-sdk ------------------------------ 62.77 KiB/175.99 KiB
# websockets ------------------------------ 71.83 KiB/180.30 KiB
# fsspec     ------------------------------ 78.62 KiB/197.85 KiB
# propcache  ------------------------------ 164.74 KiB/205.11 KiB
# charset-normalizer ------------------------------ 205.06 KiB/209.04 KiB
# opentelemetry-semantic-conventions ------------------------------ 142.79 KiB/226.19 KiB
# openpyxl   ------------------------------ 157.60 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 222.80 KiB/293.69 KiB
# lance-namespace-urllib3-client ------------------------------ 286.82 KiB/309.68 KiB
# prompt-toolkit ------------------------------ 333.46 KiB/382.26 KiB
# crewai     ------------------------------ 158.34 KiB/462.12 KiB
# huggingface-hub ------------------------------ 510.04 KiB/630.37 KiB
# crewai-tools ------------------------------ 144.00 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (4
MiB/45.36 MiB
# stagehand  ------------------------------ 35.09 MiB/35.55 MiB
# lancedb    ------------------------------ 23.02 MiB/44.50 MiB
# ⠴ Preparing packages... (148/151) 24.16 MiB/45.36 MiB
# stagehand  ------------------------------ 35.09 MiB/35.55 MiB
# lancedb    ------------------------------ 23.35 MiB/44.50 MiB
# ⠴ Preparing packages... (148/151) 24.16 MiB/45.36 MiB
# stagehand  ------------------------------ 35.09 MiB/35.55 MiB
# lancedb    ------------------------------ 23.35 MiB/44.50 MiB
# ⠴ Preparing packages... (148/151) 24.25 MiB/45.36 MiB
# stagehand  ------------------------------ 35.09 MiB/35.55 MiB
# lancedb    ------------------------------ 23.35 MiB/44.50 MiB
# ⠴ Preparing packages... (148/151) 24.27 MiB/45.36 MiB
# stagehand  ------------------------------ 35.09 MiB/35.55 MiB
# lancedb    ------------------------------ 23.35 MiB/44.50 MiB
# ⠴ Preparing packages... (148/151) 24.29 MiB/45.36 MiB
# stagehand  ------------------------------ 35.09 MiB/35.55 MiB
# lancedb    ------------------------------ 23.35 MiB/44.50 MiB
# ⠴ Preparing packages... (148/151) 25.34 MiB/45.36 MiB
# stagehand  ------------------------------ 35.09 MiB/35.55 MiB
# lancedb    ------------------------------ 25.40 MiB/44.50 MiB
# ⠴ Preparing packages... (148/151) 27.92 MiB/45.36 MiB
# stagehand  ------------------------------ 35.54 MiB/35.55 MiB
# lancedb    ------------------------------ 26.72 MiB/44.50 MiB
# ⠦ Preparing packages... (148/151) 30.89 MiB/45.36 MiB
# lancedb    ------------------------------ 28.87 MiB/44.50 MiB
# ⠦ Preparing packages... (148/151) 31.44 MiB/45.36 MiB
# lancedb    ------------------------------ 28.87 MiB/44.50 MiB
# ⠦ Preparing packages... (148/151) 31.55 MiB/45.36 MiB
# lancedb    ------------------------------ 31.58 MiB/44.50 MiB
# ⠦ Preparing packages... (148/151) 33.72 MiB/45.36 MiB
# lancedb    ------------------------------ 34.13 MiB/44.50 MiB
# ⠦ Preparing packages... (148/151) 35.15 MiB/45.36 MiB
# lancedb    ------------------------------ 35.50 MiB/44.50 MiB
# ⠧ Preparing packages... (149/151) 35.68 MiB/45.36 MiB
# lancedb    ------------------------------ 38.03 MiB/44.50 MiB
# ⠧ Preparing packages... (149/151) 36.23 MiB/45.36 MiB
# lancedb    ------------------------------ 40.69 MiB/44.50 MiB
# ⠧ Preparing packages... (149/151) 37.47 MiB/45.36 MiB
# lancedb    ------------------------------ 40.86 MiB/44.50 MiB
# ⠇ Preparing packages... (149/151) 39.47 MiB/45.36 MiB
# lancedb    ------------------------------ 41.71 MiB/44.50 MiB
# ⠇ Preparing packages... (149/151) 39.47 MiB/45.36 MiB
# lancedb    ------------------------------ 41.71 MiB/44.50 MiB
# ⠇ Preparing packages... (149/151) 39.48 MiB/45.36 MiB
# lancedb    ------------------------------ 41.71 MiB/44.50 MiB
# ⠇ Preparing packages... (149/151) 39.50 MiB/45.36 MiB
# lancedb    ------------------------------ 41.71 MiB/44.50 MiB
# ⠇ Preparing packages... (149/151) 41.28 MiB/45.36 MiB
# lancedb    ------------------------------ 44.20 MiB/44.50 MiB
# ⠋ Preparing packages... (149/151) 43.37 MiB/45.36 MiB
# ⠋ Preparing packages... (149/151) 43.57 MiB/45.36 MiB
# Prepared 151 packages in 5.27s
# Installed 151 packages in 209ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.5
#  + aiosignal==1.4.0
#  + annotated-doc==0.0.4
#  + annotated-types==0.7.0
#  + anyio==4.13.0
#  + appdirs==1.4.4
#  + asttokens==3.0.1
#  + attrs==26.1.0
#  + backoff==2.2.1
#  + bcrypt==5.0.0
#  + beautifulsoup4==4.14.3
#  + blinker==1.9.0
#  + build==1.4.3
#  + certifi==2026.2.25
#  + cffi==2.0.0
#  + charset-normalizer==3.4.7
#  + chromadb==1.1.1
#  + click==8.3.2
#  + crewai==0.203.2
#  + crewai-tools==0.76.0
#  + cryptography==46.0.7
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + deprecation==2.1.0
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.18.0
#  + durationpy==0.10
#  + et-xmlfile==2.0.0
#  + executing==2.2.1
#  + filelock==3.28.0
#  + flatbuffers==25.12.19
#  + frozenlist==1.8.0
#  + fsspec==2026.3.0
#  + googleapis-common-protos==1.74.0
#  + grpcio==1.80.0
#  + h11==0.16.0
#  + hf-xet==1.4.3
#  + httpcore==1.0.9
#  + httptools==0.7.1
#  + httpx==0.28.1
#  + huggingface-hub==1.11.0
#  + idna==3.11
#  + importlib-metadata==8.7.1
#  + importlib-resources==7.1.0
#  + instructor==1.15.1
#  + ipython==8.39.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.13.0
#  + json-repair==0.25.2
#  + json5==0.14.0
#  + jsonpickle==4.1.1
#  + jsonref==1.1.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + kubernetes==35.0.0
#  + lance-namespace==0.6.1
#  + lance-namespace-urllib3-client==0.6.1
#  + lancedb==0.30.2
#  + litellm==1.74.9
#  + lxml==6.0.4
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib-inline==0.2.1
#  + mdurl==0.1.2
#  + mmh3==5.2.1
#  + mpmath==1.3.0
#  + multidict==6.7.1
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.24.3
#  + openai==2.32.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.41.0
#  + opentelemetry-exporter-otlp-proto-common==1.41.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.41.0
#  + opentelemetry-exporter-otlp-proto-http==1.41.0
#  + opentelemetry-proto==1.41.0
#  + opentelemetry-sdk==1.41.0
#  + opentelemetry-semantic-conventions==0.62b0
#  + orjson==3.11.8
#  + overrides==7.7.0
#  + packaging==26.1
#  + parso==0.8.6
#  + pdfminer-six==20251230
#  + pdfplumber==0.11.9
#  + pexpect==4.9.0
#  + pillow==12.2.0
#  + portalocker==2.7.0
#  + posthog==5.4.0
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + protobuf==6.33.6
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==23.0.1
#  + pybase64==1.4.3
#  + pycparser==3.0
#  + pydantic==2.13.1
#  + pydantic-core==2.46.1
#  + pydantic-settings==2.13.1
#  + pygments==2.20.0
#  + pyjwt==2.12.1
#  + pypdf==6.10.2
#  + pypdfium2==5.7.0
#  + pypika==0.51.1
#  + pyproject-hooks==1.2.0
#  + python-dateutil==2.9.0.post0
#  + python-docx==1.2.0
#  + python-dotenv==1.2.2
#  + pytube==15.0.0
#  + pyvis==0.3.2
#  + pyyaml==6.0.3
#  + referencing==0.37.0
#  + regex==2026.4.4
#  + requests==2.33.1
#  + requests-oauthlib==2.0.0
#  + rich==14.3.4
#  + rpds-py==0.30.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.8.3
#  + stack-data==0.6.3
#  + stagehand==3.19.5
#  + sympy==1.14.0
#  + tenacity==9.1.4
#  + tiktoken==0.12.0
#  + tokenizers==0.22.2
#  + tomli==2.4.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.3
#  + traitlets==5.14.3
#  + typer==0.24.1
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.3
#  + uv==0.11.7
#  + uvicorn==0.44.0
#  + uvloop==0.22.1
#  + watchfiles==1.1.1
#  + wcwidth==0.6.0
#  + websocket-client==1.9.0
#  + websockets==16.0
#  + yarl==1.23.0
#  + youtube-transcript-api==1.2.4
#  + zipp==3.23.1

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 35ee9330-ad1f-4476-b5dc-105da9b4d64e                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  1. **Increased Model Sizes**: AI LLMs have shown significant advancements   │
# │  in model size, with recent models like GPT-4 exceeding 200 billion          │
# │  parameters, improving their ability to understand and generate human-like   │
# │  text.                                                                       │
# │                                                                              │
# │  2. **Multi-Modal Capabilities**: New developments allow AI LLMs to operate  │
# │  in multi-modal contexts, combining text, images, and audio inputs. For      │
# │  instance, models like DALL-E and CLIP integrate vision and language for     │
# │  enhanced task performance.                                                  │
# │                                                                              │
# │  3. **Few-Shot and Zero-Shot Learning**: New techniques have improved        │
# │  few-shot and zero-shot learning capabilities in LLMs, allowing them to      │
# │  perform tasks with minimal task-specific training data, thus broadening     │
# │  their application scope.                                                    │
# │                                                                              │
# │  4. **Energy Efficiency**: Research has focused on making LLMs more          │
# │  energy-efficient, with methods such as model distillation and quantization  │
# │  significantly reducing carbon footprints associated with training and       │
# │  deploying these models.                                                     │
# │                                                                              │
# │  5. **Ethical AI Initiatives**: There is an increased focus on addressing    │
# │  ethical concerns related to AI LLMs, including bias mitigation,             │
# │  transparency, and responsible usage. Organizations are actively developing  │
# │  guidelines and frameworks for ethical AI deployment.                        │
# │                                                                              │
# │  6. **Federated Learning Applications**: AI LLMs are increasingly utilizing  │
# │  federated learning techniques to enhance privacy and security. This allows  │
# │  models to learn from decentralized data sources without compromising        │
# │  individual data privacy.                                                    │
# │                                                                              │
# │  7. **Personalization Features**: Recent advancements enable LLMs to         │
# │  provide more personalized interactions. By incorporating user-specific      │
# │  data and preferences, these models can tailor responses for improved user   │
# │  experience.                                                                 │
# │                                                                              │
# │  8. **Collaborative AI Tools**: The integration of AI LLMs into              │
# │  collaboration tools enhances productivity. For instance, services like      │
# │  Google Workspace and Microsoft 365 are embedding LLMs to assist with        │
# │  writing, data analysis, and task management.                                │
# │                                                                              │
# │  9. **Open-Source Model Growth**: There is a proliferation of open-source    │
# │  LLMs, driven by communities seeking to democratize AI technology.           │
# │  Initiatives like EleutherAI and Hugging Face's Transformers library have    │
# │  made powerful models accessible for research and development.               │
# │                                                                              │
# │  10. **Regulatory Developments**: Governments and international bodies are   │
# │  beginning to formulate regulations surrounding AI technologies, focusing    │
# │  on accountability, data governance, and the ethical implications of LLM     │
# │  deployment, thereby shaping the future landscape of AI LLM applications.    │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: research_task                                                         │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: f4d82582-b02a-4630-bf93-a7966ccbfcbe)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: f4d82582-b02a-4630-bf93-a7966ccbfcbe)
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: f4d82582-b02a-4630-bf93-a7966ccbfcbe)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Comprehensive Report on Recent Developments in AI LLMs                    │
# │                                                                              │
# │  ## 1. Increased Model Sizes                                                 │
# │  Recent advancements in AI Large Language Models (LLMs) have prominently     │
# │  featured an increase in model sizes, with state-of-the-art implementations  │
# │  such as GPT-4 exceeding an impressive 200 billion parameters. This          │
# │  monumental growth in model size has resulted in significant enhancements    │
# │  to their understanding and generation of human-like text. The expansion     │
# │  allows these models to capture more complex language patterns and context,  │
# │  leading to better coherence, relevance, and overall quality in text         │
# │  generation. Furthermore, larger models can accommodate more nuanced         │
# │  information, improving their performance across a multitude of              │
# │  applications, from conversational agents to sophisticated content creation  │
# │  tools. However, these advancements also raise important considerations      │
# │  regarding computational resource requirements and environmental impact.     │
# │                                                                              │
# │  ## 2. Multi-Modal Capabilities                                              │
# │  The evolution of AI LLMs has been marked by the emergence of multi-modal    │
# │  capabilities, integrating text, images, and audio inputs to improve         │
# │  performance across various tasks. Models like DALL-E and CLIP exemplify     │
# │  this trend by enabling the synthesis of visual and textual content,         │
# │  thereby expanding the horizons of what LLMs can achieve. For instance,      │
# │  DALL-E can generate unique images based on textual descriptions, while      │
# │  CLIP can analyze visual content and generate relevant text responses.       │
# │  These capabilities facilitate a more comprehensive interaction with AI,     │
# │  making it not only a textual assistant but also a versatile tool for        │
# │  creative and academic endeavors. The integration of multiple modalities     │
# │  fosters more intuitive and efficient user experiences.                      │
# │                                                                              │
# │  ## 3. Few-Shot and Zero-Shot Learning                                       │
# │  Recent innovations in few-shot and zero-shot learning have enabled LLMs to  │
# │  perform various tasks with significantly reduced amounts of task-specific   │
# │  training data. This development broadens their application scope            │
# │  dramatically, allowing models to adapt to novel tasks quickly without the   │
# │  necessity of extensive retraining. With few-shot learning, models can       │
# │  leverage existing knowledge to tackle new challenges after being exposed    │
# │  to only a handful of examples. Conversely, zero-shot learning allows them   │
# │  to apply their reasoning and comprehension skills to unfamiliar tasks       │
# │  entirely, paving the way for versatile applications in domains like         │
# │  customer service, education, and content generation. These techniques       │
# │  reduce the dependency on large labeled datasets, making AI technology more  │
# │  accessible.                                                                 │
# │                                                                              │
# │  ## 4. Energy Efficiency                                                     │
# │  As concerns over the carbon footprint and energy consumption of training    │
# │  large models have grown, research has increasingly focused on enhancing     │
# │  the energy efficiency of LLMs. Techniques such as model distillation,       │
# │  where a smaller model learns to replicate the behavior of a larger one,     │
# │  and quantization, which reduces the precision of numbers used in            │
# │  computations, are being implemented effectively. These innovations can      │
# │  lead to substantial reductions in the energy requirements associated with   │
# │  training and deploying models, addressing both environmental and            │
# │  cost-related concerns. As AI technology continues to expand, improving      │
# │  sustainability practices will be crucial in ensuring responsible            │
# │  advancement.                                                                │
# │                                                                              │
# │  ## 5. Ethical AI Initiatives                                                │
# │  With the rapid proliferation of AI technologies, an increasing emphasis on  │
# │  ethical AI initiatives has emerged, aimed at addressing key concerns        │
# │  related to AI LLMs. Important focus areas include bias mitigation,          │
# │  transparency, and the responsible usage of AI tools. Organizations and      │
# │  researchers are developing guidelines and frameworks to ensure ethical AI   │
# │  deployment, striving to create systems that are trustworthy and equitable.  │
# │  This includes efforts to audit models for bias, implement fair practices    │
# │  in their development and application, and establish accountability          │
# │  standards. The collaboration between technologists, ethicists, and          │
# │  policymakers is essential to shape a responsible AI landscape.              │
# │                                                                              │
# │  ## 6. Federated Learning Applications                                       │
# │  Federated learning techniques are gaining traction in the development of    │
# │  AI LLMs, enhancing the models' ability to learn from decentralized data     │
# │  sources while maintaining individual privacy. Instead of relying on         │
# │  centralized datasets, where sensitive information may be at risk,           │
# │  federated learning allows models to train on data locally across multiple   │
# │  devices or servers. This methodology not only preserves user privacy but    │
# │  also enhances data security, as information remains on users' devices       │
# │  rather than being transmitted to a centralized server. By leveraging        │
# │  federated learning, organizations can build more robust AI models while     │
# │  respecting individual rights.                                               │
# │                                                                              │
# │  ## 7. Personalization Features                                              │
# │  Cutting-edge advancements in AI LLMs have introduced sophisticated          │
# │  personalization features, enabling models to provide tailored interactions  │
# │  based on user-specific data and preferences. Implementing user profiling    │
# │  and adaptive algorithms allows LLMs to customize content and responses to   │
# │  align with the user's interests, improving overall user experience. This    │
# │  personalization can enhance applications in various fields such as          │
# │  marketing, e-commerce, and customer service, ensuring that interactions     │
# │  are relevant and engaging. As more businesses recognize the value of        │
# │  personalized user experiences, LLMs equipped with these features will play  │
# │  a pivotal role in driving user satisfaction and loyalty.                    │
# │                                                                              │
# │  ## 8. Collaborative AI Tools                                                │
# │  The integration of AI LLMs into collaborative tools has significantly       │
# │  enhanced productivity across various sectors. Platforms like Google         │
# │  Workspace and Microsoft 365 are embedding LLM capabilities to assist users  │
# │  in tasks such as writing, data analysis, and project management. By         │
# │  providing contextual suggestions, automated formatting, and error-checking  │
# │  functionalities, these AI tools can streamline workflows and reduce the     │
# │  time required for routine tasks. Furthermore, collaborative AI fosters a    │
# │  more interactive environment, enabling teams to harness the power of        │
# │  AI-generated insights and facilitate better communication. This             │
# │  integration signifies a transformative shift in how professionals interact  │
# │  with technology.                                                            │
# │                                                                              │
# │  ## 9. Open-Source Model Growth                                              │
# │  The open-source movement surrounding AI LLMs is flourishing, driven by      │
# │  communities that aim to democratize access to AI technology. Initiatives    │
# │  like EleutherAI and Hugging Face's Transformers library are making          │
# │  powerful models available for research and development purposes, fostering  │
# │  collaboration and innovation in the AI ecosystem. This open-source          │
# │  framework allows researchers, developers, and organizations to experiment   │
# │  with and customize AI models, ultimately accelerating advancements in the   │
# │  field. By breaking down barriers to entry and encouraging shared learning,  │
# │  the open-source growth propels the collective development of AI             │
# │  technologies.                                                               │
# │                                                                              │
# │  ## 10. Regulatory Developments                                              │
# │  The growing influence of AI technologies has prompted governments and       │
# │  international bodies to begin crafting regulations related to AI,           │
# │  particularly in the context of accountability, data governance, and         │
# │  ethical implications. These regulatory frameworks aim to ensure             │
# │  responsible AI usage and protect citizens from potential harms arising      │
# │  from AI deployment. Policymakers are grappling with the challenges of       │
# │  keeping pace with rapid technological advancements while ensuring public    │
# │  trust and safety. As the regulatory landscape continues to evolve, it will  │
# │  play a crucial role in shaping the future deployment of AI LLMs and         │
# │  fostering a responsible AI ecosystem.                                       │
# │                                                                              │
# │  This comprehensive examination of AI LLM developments reflects the rapid    │
# │  progress and intricate considerations inherent in this field. The ongoing   │
# │  advancements not only demonstrate the incredible potential of AI            │
# │  technologies but also highlight the importance of responsible innovation    │
# │  and ethical practices in shaping a beneficial future for all stakeholders.  │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 1f5acd88-8d7e-4fc7-b6e0-7e4a1b46e03d)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: f4d82582-b02a-4630-bf93-a7966ccbfcbe)
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: reporting_task                                                        │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 35ee9330-ad1f-4476-b5dc-105da9b4d64e                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Comprehensive Report on Recent Developments in AI LLMs      │
# │                                                                              │
# │  ## 1. Increased Model Sizes                                                 │
# │  Recent advancements in AI Large Language Models (LLMs) have prominently     │
# │  featured an increase in model sizes, with state-of-the-art implementations  │
# │  such as GPT-4 exceeding an impressive 200 billion parameters. This          │
# │  monumental growth in model size has resulted in significant enhancements    │
# │  to their understanding and generation of human-like text. The expansion     │
# │  allows these models to capture more complex language patterns and context,  │
# │  leading to better coherence, relevance, and overall quality in text         │
# │  generation. Furthermore, larger models can accommodate more nuanced         │
# │  information, improving their performance across a multitude of              │
# │  applications, from conversational agents to sophisticated content creation  │
# │  tools. However, these advancements also raise important considerations      │
# │  regarding computational resource requirements and environmental impact.     │
# │                                                                              │
# │  ## 2. Multi-Modal Capabilities                                              │
# │  The evolution of AI LLMs has been marked by the emergence of multi-modal    │
# │  capabilities, integrating text, images, and audio inputs to improve         │
# │  performance across various tasks. Models like DALL-E and CLIP exemplify     │
# │  this trend by enabling the synthesis of visual and textual content,         │
# │  thereby expanding the horizons of what LLMs can achieve. For instance,      │
# │  DALL-E can generate unique images based on textual descriptions, while      │
# │  CLIP can analyze visual content and generate relevant text responses.       │
# │  These capabilities facilitate a more comprehensive interaction with AI,     │
# │  making it not only a textual assistant but also a versatile tool for        │
# │  creative and academic endeavors. The integration of multiple modalities     │
# │  fosters more intuitive and efficient user experiences.                      │
# │                                                                              │
# │  ## 3. Few-Shot and Zero-Shot Learning                                       │
# │  Recent innovations in few-shot and zero-shot learning have enabled LLMs to  │
# │  perform various tasks with significantly reduced amounts of task-specific   │
# │  training data. This development broadens their application scope            │
# │  dramatically, allowing models to adapt to novel tasks quickly without the   │
# │  necessity of extensive retraining. With few-shot learning, models can       │
# │  leverage existing knowledge to tackle new challenges after being exposed    │
# │  to only a handful of examples. Conversely, zero-shot learning allows them   │
# │  to apply their reasoning and comprehension skills to unfamiliar tasks       │
# │  entirely, paving the way for versatile applications in domains like         │
# │  customer service, education, and content generation. These techniques       │
# │  reduce the dependency on large labeled datasets, making AI technology more  │
# │  accessible.                                                                 │
# │                                                                              │
# │  ## 4. Energy Efficiency                                                     │
# │  As concerns over the carbon footprint and energy consumption of training    │
# │  large models have grown, research has increasingly focused on enhancing     │
# │  the energy efficiency of LLMs. Techniques such as model distillation,       │
# │  where a smaller model learns to replicate the behavior of a larger one,     │
# │  and quantization, which reduces the precision of numbers used in            │
# │  computations, are being implemented effectively. These innovations can      │
# │  lead to substantial reductions in the energy requirements associated with   │
# │  training and deploying models, addressing both environmental and            │
# │  cost-related concerns. As AI technology continues to expand, improving      │
# │  sustainability practices will be crucial in ensuring responsible            │
# │  advancement.                                                                │
# │                                                                              │
# │  ## 5. Ethical AI Initiatives                                                │
# │  With the rapid proliferation of AI technologies, an increasing emphasis on  │
# │  ethical AI initiatives has emerged, aimed at addressing key concerns        │
# │  related to AI LLMs. Important focus areas include bias mitigation,          │
# │  transparency, and the responsible usage of AI tools. Organizations and      │
# │  researchers are developing guidelines and frameworks to ensure ethical AI   │
# │  deployment, striving to create systems that are trustworthy and equitable.  │
# │  This includes efforts to audit models for bias, implement fair practices    │
# │  in their development and application, and establish accountability          │
# │  standards. The collaboration between technologists, ethicists, and          │
# │  policymakers is essential to shape a responsible AI landscape.              │
# │                                                                              │
# │  ## 6. Federated Learning Applications                                       │
# │  Federated learning techniques are gaining traction in the development of    │
# │  AI LLMs, enhancing the models' ability to learn from decentralized data     │
# │  sources while maintaining individual privacy. Instead of relying on         │
# │  centralized datasets, where sensitive information may be at risk,           │
# │  federated learning allows models to train on data locally across multiple   │
# │  devices or servers. This methodology not only preserves user privacy but    │
# │  also enhances data security, as information remains on users' devices       │
# │  rather than being transmitted to a centralized server. By leveraging        │
# │  federated learning, organizations can build more robust AI models while     │
# │  respecting individual rights.                                               │
# │                                                                              │
# │  ## 7. Personalization Features                                              │
# │  Cutting-edge advancements in AI LLMs have introduced sophisticated          │
# │  personalization features, enabling models to provide tailored interactions  │
# │  based on user-specific data and preferences. Implementing user profiling    │
# │  and adaptive algorithms allows LLMs to customize content and responses to   │
# │  align with the user's interests, improving overall user experience. This    │
# │  personalization can enhance applications in various fields such as          │
# │  marketing, e-commerce, and customer service, ensuring that interactions     │
# │  are relevant and engaging. As more businesses recognize the value of        │
# │  personalized user experiences, LLMs equipped with these features will play  │
# │  a pivotal role in driving user satisfaction and loyalty.                    │
# │                                                                              │
# │  ## 8. Collaborative AI Tools                                                │
# │  The integration of AI LLMs into collaborative tools has significantly       │
# │  enhanced productivity across various sectors. Platforms like Google         │
# │  Workspace and Microsoft 365 are embedding LLM capabilities to assist users  │
# │  in tasks such as writing, data analysis, and project management. By         │
# │  providing contextual suggestions, automated formatting, and error-checking  │
# │  functionalities, these AI tools can streamline workflows and reduce the     │
# │  time required for routine tasks. Furthermore, collaborative AI fosters a    │
# │  more interactive environment, enabling teams to harness the power of        │
# │  AI-generated insights and facilitate better communication. This             │
# │  integration signifies a transformative shift in how professionals interact  │
# │  with technology.                                                            │
# │                                                                              │
# │  ## 9. Open-Source Model Growth                                              │
# │  The open-source movement surrounding AI LLMs is flourishing, driven by      │
# │  communities that aim to democratize access to AI technology. Initiatives    │
# │  like EleutherAI and Hugging Face's Transformers library are making          │
# │  powerful models available for research and development purposes, fostering  │
# │  collaboration and innovation in the AI ecosystem. This open-source          │
# │  framework allows researchers, developers, and organizations to experiment   │
# │  with and customize AI models, ultimately accelerating advancements in the   │
# │  field. By breaking down barriers to entry and encouraging shared learning,  │
# │  the open-source growth propels the collective development of AI             │
# │  technologies.                                                               │
# │                                                                              │
# │  ## 10. Regulatory Developments                                              │
# │  The growing influence of AI technologies has prompted governments and       │
# │  international bodies to begin crafting regulations related to AI,           │
# │  particularly in the context of accountability, data governance, and         │
# │  ethical implications. These regulatory frameworks aim to ensure             │
# │  responsible AI usage and protect citizens from potential harms arising      │
# │  from AI deployment. Policymakers are grappling with the challenges of       │
# │  keeping pace with rapid technological advancements while ensuring public    │
# │  trust and safety. As the regulatory landscape continues to evolve, it will  │
# │  play a crucial role in shaping the future deployment of AI LLMs and         │
# │  fostering a responsible AI ecosystem.                                       │
# │                                                                              │
# │  This comprehensive examination of AI LLM developments reflects the rapid    │
# │  progress and intricate considerations inherent in this field. The ongoing   │
# │  advancements not only demonstrate the incredible potential of AI            │
# │  technologies but also highlight the importance of responsible innovation    │
# │  and ethical practices in shaping a beneficial future for all stakeholders.  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
#
#
# ╭────────────────────────────── Execution Traces ──────────────────────────────╮
# │                                                                              │
# │  🔍 Detailed execution traces are available!                                 │
# │                                                                              │
# │  View insights including:                                                    │
# │    • Agent decision-making process                                           │
# │    • Task execution flow and timing                                          │
# │    • Tool usage details                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
